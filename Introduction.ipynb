# %%
rock_scissors_paper = ['rock','scissors','data']
player1='rock'
player2='scissors'
if player1==player2:
    print('Even!')
elif player1=='rock':
    if player2=='scissors':
        print('Player1 wins')
    else:
        print('player2 wins')
elif player1== 'scissors':
    if player2=='paper':
        print('player1 wins')
    else:
        print('player2 wins')
elif player1== 'paper':
    if player2=='rock':
        print('player1 wins')
    else:
        print('player2 wins')
# Out:
# Player1 wins

# %%
import numpy as np
def play(player1):
    index2=np.random.randint(0,3)
    player2=rock_scissors_paper[index2]
    return player2

# %%
play('a')
# Out:
# 'scissors'

# %%
'''Standard_Scaler'''
# Out:
# 'Standard_Scaler'

# %%
import numpy as np
a=np.array([1,2,3,4,5])
z=(a-np.mean(a))/np.std(a)
z
# Out:
# array([-1.41421356, -0.70710678,  0.        ,  0.70710678,  1.41421356])

# %%
np.std(z)
# Out:
# 0.9999999999999999

# %%
np.mean(z)
# Out:
# 0.0

# %%
# !pip install scikit-learn
from sklearn.preprocessing import StandardScaler

# %%
'''Splitting the dataset'''

# %%
import pandas as pd
import os

# %%
pwd
# Out:
# 'c:\\Users\\mahen\\OneDrive\\Desktop\\test\\Pandas\\Matplotlib'

# %%
df=pd.read_csv(r'c:\\Users\\mahen\\OneDrive\\Desktop\\diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
X=df.drop('Outcome', axis=1)
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
y=df['Outcome']
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, y_train, X_test, y_test = train_test_split(X,y, test_size=0.33, random_state=42)

# %%
X_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 464           10      115             98              0        0  24.0
# 223            7      142             60             33      190  28.8
# 393            4      116             72             12       87  22.1
# 766            1      126             60              0        0  30.1
# 570            3       78             70              0        0  32.5
# ..           ...      ...            ...            ...      ...   ...
# 71             5      139             64             35      140  28.6
# 106            1       96            122              0        0  22.4
# 270           10      101             86             37        0  45.6
# 435            0      141              0              0        0  42.4
# 102            0      125             96              0        0  22.5
#
#      DiabetesPedigreeFunction  Age
# 464                     1.022   34
# 223                     0.687   61
# ...

# %%
y_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 668            6       98             58             33      190  34.0
# 324            2      112             75             32        0  35.7
# 624            2      108             64              0        0  30.8
# 690            8      107             80              0        0  24.6
# 473            7      136             90              0        0  29.9
# ..           ...      ...            ...            ...      ...   ...
# 311            0      106             70             37      148  39.4
# 429            1       95             82             25      180  35.0
# 182            1        0             74             20       23  27.7
# 586            8      143             66              0        0  34.9
# 679            2      101             58             17      265  24.2
#
#      DiabetesPedigreeFunction  Age
# 668                     0.430   43
# 324                     0.148   21
# ...

# %%
'''KFold Cross validation'''

# %%
from sklearn.model_selection import KFold

# %%
kf= KFold(n_splits=2, shuffle=True)

# %%
kf.split(X)
# Out:
# <generator object _BaseKFold.split at 0x0000026D1FB8C820>

# %%
for train, val in kf.split(X):
    print('Training indices:', train)
    print(len(train))
    print('Validation indices:', val)
    print(len(val))
# Out:
# Training indices: [  0   2   3   4   7   9  11  12  14  15  17  18  20  23  27  28  29  30
#   31  34  36  37  39  42  43  44  46  47  48  49  50  53  54  55  57  61
#   63  69  71  73  75  81  83  86  87  88  89  90  91  92  94  95  96  97
#   98 104 105 106 108 109 111 116 119 120 121 125 129 131 133 136 137 138
#  140 141 142 145 152 153 155 156 158 160 162 163 167 172 174 175 178 179
#  181 182 183 189 190 192 193 197 199 200 207 209 211 213 214 215 216 217
#  219 222 223 225 236 239 245 247 248 249 253 260 261 263 264 265 266 267
#  268 271 273 274 276 277 279 280 281 283 286 287 288 289 292 293 294 295
#  298 300 301 303 304 305 312 315 317 318 319 322 323 324 325 326 327 328
#  329 330 333 337 338 339 340 344 346 350 352 353 354 355 356 357 358 359
#  362 364 365 366 367 369 371 374 377 378 379 380 381 382 383 386 388 389
#  392 393 395 397 398 399 400 402 404 411 412 413 415 416 417 418 419 420
#  422 424 425 427 429 431 433 434 435 436 438 439 440 443 446 448 449 450
# ...

# %%
X.loc[train]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# 10             4      110             92              0        0  37.6
# ..           ...      ...            ...            ...      ...   ...
# 759            6      190             92              0        0  35.5
# 762            9       89             62              0        0  22.5
# 764            2      122             70             27        0  36.8
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 1                       0.351   31
# 5                       0.201   30
# ...

# %%
X.loc[val]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 7             10      115              0              0        0  35.3
# ..           ...      ...            ...            ...      ...   ...
# 758            1      106             76              0        0  37.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31        0  44.0
# 763           10      101             76             48      180  32.9
# 765            5      121             72             23      112  26.2
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 2                       0.672   32
# ...

# %%
y.loc[train]
# Out:
# 1      0
# 5      0
# 6      1
# 8      1
# 10     0
#       ..
# 759    1
# 762    0
# 764    0
# 766    1
# 767    0
# Name: Outcome, Length: 384, dtype: int64

# %%
y.loc[val]
# Out:
# 0      1
# 2      1
# 3      0
# 4      1
# 7      0
#       ..
# 758    0
# 760    0
# 761    1
# 763    0
# 765    0
# Name: Outcome, Length: 384, dtype: int64
